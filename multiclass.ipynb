# %%
#DAY 2 OF INTRODUCTION TO MACHINE LEARNING.
# THIS SECOND NOTEBOOK EXPLORES MULTICLASS CLASSIFICATION.
# AUTHOR: LAWRENCE
# BOOK USED: INTRO TO MACHINE LEARNING
# LETS DIVE IN.

# %%
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt 
#import seaborn as sns; sns.set() 
import mglearn

X, y = make_blobs(random_state=42)

#BYPASSING THE MGLEARN MODULE.

mglearn.discrete_scatter(X[: , 0], X[:, 1], y)
plt.xlabel("Feature 0")
plt.ylabel("Feature 1")
plt.legend(["Class 0", "Class 1", "Class 2"])

# %%
# NOW TRAINNING LINEAR SCV 
from sklearn.svm import LinearSVC

linear_svm = LinearSVC().fit(X, y)
print("Coefficient shape: ", linear_svm.coef_.shape)
print("Intercept shape: ", linear_svm.intercept_.shape)
# Out:
# Coefficient shape:  (3, 2)
# Intercept shape:  (3,)

# %%
import numpy as np
mglearn.discrete_scatter(X[:, 0], X[:, 1], y)
line = np.linspace(-15, 15)
for coef, intercept , color in zip(linear_svm.coef_, linear_svm.intercept_,
                ['b','r', 'g']):
    plt.plot(line, -(line * coef[0] + intercept) / coef[1], c=color)

plt.ylim(-10, 15)
plt.xlim(-10, 8)
plt.xlabel("Feature 0")
plt.ylabel("Feature 1")
plt.legend(['Class 0', 'Class 1', 'Class 2', 'Line class 0', 'Line class 1', 'Line class 2'], loc=(1.01, 0.3))

# %% [markdown]
# NAIVE BAYES CLASSIFIERS.

# %%
x = np.array([[ 0, 1, 0, 1],
              [1, 0, 1, 1],
              [0, 0, 0, 1],
              [1, 0, 1, 0]])

y =np.array([0, 1, 0, 1])

# %%
counts = {}
for label in np.unique(y):
    # iterate over each class
    # count (sum) entries of 1 per Feature

    counts[label] = x[y == label].sum(axis=0)

print("Featue counts: \n {}".format(counts))
# Out:
# Featue counts:
#  {0: array([0, 1, 0, 2]), 1: array([2, 0, 2, 1])}

# %%
x.shape
# Out:
# (4, 4)

# %% [markdown]
# BINARY TREES.

# %%
mglearn.plots.plot_animal_tree()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-68d9ec4b28dc> in <module>
# ----> 1 mglearn.plots.plot_animal_tree()
#
# NameError: name 'mglearn' is not defined
